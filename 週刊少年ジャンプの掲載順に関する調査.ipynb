# %% [markdown]
# <a href="https://colab.research.google.com/github/abay-qkt/madb-exploration/blob/main/%E9%80%B1%E5%88%8A%E5%B0%91%E5%B9%B4%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%97%E3%81%AE%E6%8E%B2%E8%BC%89%E9%A0%86%E3%81%AB%E9%96%A2%E3%81%99%E3%82%8B%E8%AA%BF%E6%9F%BB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 週刊少年ジャンプの作品の掲載順に関する情報を抽出して、pandasやplotlyで集計・可視化してみました。

# %% [markdown]
# # 準備

# %%
# !pip install sparqlwrapper
# Out:
# Collecting sparqlwrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1 (from sparqlwrapper)
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 6.9 MB/s eta 0:00:00
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=6.1.1->sparqlwrapper)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->sparqlwrapper) (3.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->sparqlwrapper) (1.16.0)
# Installing collected packages: isodate, rdflib, sparqlwrapper
# Successfully installed isodate-0.6.1 rdflib-7.0.0 sparqlwrapper-2.0.0

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
from SPARQLWrapper import SPARQLWrapper

# エンドポイントの設定
sparql = SPARQLWrapper(endpoint='https://mediaarts-db.artmuseums.go.jp/sparql', returnFormat='json')

# クエリを投げてDataFrameを返す関数
def read_sparql(query):
  sparql.setQuery(query)
  response = sparql.queryAndConvert()  # 辞書形式で結果を受け取る
  df = pd.DataFrame(response["results"]["bindings"]).applymap(lambda x:x["value"])  # DataFrameに変換する
  df = df[response["head"]["vars"]]  # 列の並び替え
  return df

# %% [markdown]
# # 準備

# %% [markdown]
# ## データロード

# %%
query = """
PREFIX rdfs:   <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <https://schema.org/>
PREFIX class:  <https://mediaarts-db.bunka.go.jp/data/class#>
PREFIX xsd:    <http://www.w3.org/2001/XMLSchema#>

SELECT
    ?公開年月日
    ?ラベル
    ?タイトル
    ?サブタイトル
    ?開始ページ
    ?終了ページ
WHERE {
    ?リソース schema:isPartOf <https://mediaarts-db.bunka.go.jp/id/C119459> ;
    schema:genre "マンガ雑誌単号" ;
    rdfs:label ?ラベル ;
    schema:datePublished ?公開年月日 ;
    schema:hasPart [
        schema:genre "マンガ作品" ;
        schema:name ?タイトル ;
        schema:alternativeHeadline ?サブタイトル ;
        schema:pageStart ?開始ページ ;
        schema:pageEnd ?終了ページ
    ].
}
ORDER BY ?公開年月日 xsd:float(?開始ページ)
"""
df = read_sparql(query)

# %%
df.head(10)
# Out:
#         公開年月日                    ラベル       タイトル  \
# 0  1969-11-03  週刊少年ジャンプ 1969年 表示号数20     ハレンチ学園
# 1  1969-11-03  週刊少年ジャンプ 1969年 表示号数20         モサ
# 2  1969-11-03  週刊少年ジャンプ 1969年 表示号数20  まんがコント55号
# 3  1969-11-03  週刊少年ジャンプ 1969年 表示号数20     どうどう野郎
# 4  1969-11-03  週刊少年ジャンプ 1969年 表示号数20    男一匹ガキ大将
# 5  1969-11-03  週刊少年ジャンプ 1969年 表示号数20   赤塚ギャグ笑待席
# 6  1969-11-03  週刊少年ジャンプ 1969年 表示号数20  鹿兵のケラケラ日記
# 7  1969-11-03  週刊少年ジャンプ 1969年 表示号数20     デロリンマン
# 8  1969-11-03  週刊少年ジャンプ 1969年 表示号数20       黄金仮面
# 9  1969-11-03  週刊少年ジャンプ 1969年 表示号数20     挑戦者ケーン
#
#                                     サブタイトル  開始ページ  終了ページ
# 0                                    赤い嵐の巻    7.0   37.0
# 1                                  盗まれた金の巻   39.0   53.0
# 2                                  ゆうかい魔の巻   54.0   55.0
# 3                                    転校生の巻   56.0   70.0
# 4                                 万吉仁王立ちの巻   71.0  101.0
# 5                                   ゲバゲバ兄弟  103.0  117.0
# 6  スポーツの秋　／　味覚の秋　／　ラムダロケットまたしっぱい　／　あみものの季節  118.0  119.0
# 7                                  救世主誕生の巻  120.0  134.0
# 8                                    くずれる顔  135.0  165.0
# 9                              おれは挑戦する!の巻①  248.0  262.0

# %%
df.dtypes
# Out:
# 公開年月日     object
# ラベル       object
# タイトル      object
# サブタイトル    object
# 開始ページ     object
# 終了ページ     object
# dtype: object

# %% [markdown]
# いったんすべてobject型で読み込んでいます

# %% [markdown]
# ## 前処理

# %%
# 全部文字列になっているので、適切な型に変換する
df["公開年月日"]=pd.to_datetime(df["公開年月日"])
df["開始ページ"]=df["開始ページ"].astype(float).astype(int)
df["終了ページ"]=df["終了ページ"].astype(float).astype(int)

df["年"]=df["ラベル"].str.extract(r"週刊少年ジャンプ (\d{4})年 表示号数").astype(int)  # 年を抽出
df["号"] = df["ラベル"].str.extract(r"表示号数(\d+)").astype(int)  # 号を抽出
df["年_号"]=df["年"].astype(str)+"_"+df["号"].astype(str).str.zfill(2) # 年_号(2桁)

df=df.sort_values(["年_号","開始ページ"]).reset_index(drop=True)  # ソート

# %%
df["作品ページ数"] = df["終了ページ"]-df["開始ページ"] # 各タイトルのページ数
df = df[df["作品ページ数"]>10].reset_index(drop=True)  # 本編以外のものが混ざってそうだったので、ざっくりページ数で判断して除外
df = df.drop_duplicates(subset=["年_号","タイトル"],keep='first').reset_index(drop=True) # 複数同時掲載の場合最初の1本だけ分析対象にする(今回掲載順位を見たいので)

# %%
df["掲載順位"] = df.groupby(["年_号"])["開始ページ"].rank().astype(int)  # 掲載順位
df["掲載作品数"] = df.groupby(["年_号"])["タイトル"].transform("count")  # 掲載作品数
df["スコア"] = (df["掲載作品数"]-df["掲載順位"]+1) / df["掲載作品数"]  # 1位が1、最下位が0になるよう正規化した得点を付与

# %%
df.head(5)
# Out:
#        公開年月日                    ラベル      タイトル    サブタイトル  開始ページ  終了ページ     年  \
# 0 1969-11-03  週刊少年ジャンプ 1969年 表示号数20    ハレンチ学園     赤い嵐の巻      7     37  1969
# 1 1969-11-03  週刊少年ジャンプ 1969年 表示号数20        モサ   盗まれた金の巻     39     53  1969
# 2 1969-11-03  週刊少年ジャンプ 1969年 表示号数20    どうどう野郎     転校生の巻     56     70  1969
# 3 1969-11-03  週刊少年ジャンプ 1969年 表示号数20   男一匹ガキ大将  万吉仁王立ちの巻     71    101  1969
# 4 1969-11-03  週刊少年ジャンプ 1969年 表示号数20  赤塚ギャグ笑待席    ゲバゲバ兄弟    103    117  1969
#
#     号      年_号  作品ページ数  掲載順位  掲載作品数       スコア
# 0  20  1969_20      30     1      9  1.000000
# 1  20  1969_20      14     2      9  0.888889
# 2  20  1969_20      14     3      9  0.777778
# 3  20  1969_20      30     4      9  0.666667
# 4  20  1969_20      14     5      9  0.555556

# %% [markdown]
# ## 注意事項

# %%
# 次の号の公開年月日の方が早いデータが確認された
# 1971          荒野の少年イサム(1.3)           男一匹ガキ大将(2.6)
# 1972          荒野の少年イサム(2.1)           男一匹ガキ大将(2.5)
# 1973          荒野の少年イサム(2.5)             大ぼら一代(2.7)
# 1974              炎の巨人(2.5)             大ぼら一代(3.2)
# 1975             ゼロの白鷹(3.5)          ドーベルマン刑事(4.4)
# 1976           サーキットの狼(3.3)          ドーベルマン刑事(5.1)
# 1977           サーキットの狼(2.9)          JUMP民話劇場(3.2)
# 1978           さわやか万太郎(3.6)        すすめ!!パイレーツ(4.2)
# 1979           さわやか万太郎(3.6)            テニスボーイ(4.3)
# 1980             山崎銀次郎(2.3)           Dr.スランプ(4.0)
# 1981           Dr.スランプ(2.5)             山崎銀次郎(4.1)
# 1982            風魔の小次郎(3.0)      ストップ!!ひばりくん!(3.7)
# 1983            天地を喰らう(2.6)             キン肉マン(4.6)
# 1984              北斗の拳(3.3)             キン肉マン(3.6)
# 1985              北斗の拳(2.7)       DRAGON　BALL(5.2)
# 1986              北斗の拳(2.6)       DRAGON　BALL(3.9)
# 1987       DRAGON　BALL(3.3)              北斗の拳(3.6)
# 1988       DRAGON　BALL(3.1)             聖闘士星矢(4.0)
# 1989       DRAGON　BALL(3.1)             魁!!男塾(4.8)
# 1990       DRAGON　BALL(3.0)        ろくでなしBLUES(3.3)
# 1991       DRAGON　BALL(2.8)        ろくでなしBLUES(3.9)
# 1992       DRAGON　BALL(2.8)         SLAM　DUNK(3.4)
# 1993       DRAGON　BALL(2.9)         SLAM　DUNK(3.4)
# 1994       DRAGON　BALL(2.5)         SLAM　DUNK(3.6)
# 1995       DRAGON　BALL(2.6)         SLAM　DUNK(3.5)
# 1996         SLAM　DUNK(3.1)  るろうに剣心 -明治剣客浪漫譚-(3.6)
# 1997  るろうに剣心 -明治剣客浪漫譚-(2.7)         ONE PIECE(3.7)
# 1998         ONE PIECE(2.1)  るろうに剣心 -明治剣客浪漫譚-(3.1)
# 1999         ONE PIECE(2.1)     HUNTER×HUNTER(4.3)
# 2000         ONE PIECE(2.1)             ヒカルの碁(5.1)
# 2001         ONE PIECE(2.7)       NARUTO-ナルト-(3.9)
# 2002         ONE PIECE(3.0)           テニスの王子様(3.6)
# 2003         ONE PIECE(2.6)       NARUTO-ナルト-(3.5)
# 2004         ONE PIECE(2.3)       NARUTO-ナルト-(2.9)
# 2005       NARUTO-ナルト-(2.4)         ONE PIECE(2.5)
# 2006         ONE PIECE(2.4)       NARUTO-ナルト-(3.4)
# 2007         ONE PIECE(2.1)       NARUTO-ナルト-(3.3)
# 2008         ONE PIECE(2.3)       NARUTO-ナルト-(3.0)
# 2009         ONE PIECE(2.2)       NARUTO-ナルト-(2.2)
# 2010         ONE PIECE(2.2)       NARUTO-ナルト-(2.4)
# 2011         ONE PIECE(2.1)       NARUTO-ナルト-(3.0)
# 2012         ONE PIECE(2.5)       NARUTO-ナルト-(3.4)
# 2013         ONE PIECE(2.2)              暗殺教室(3.1)
# 2014         ONE PIECE(2.3)              暗殺教室(3.4)
# 2015         ONE PIECE(2.3)              暗殺教室(3.5)
# 2016         ONE PIECE(2.2)       僕のヒーローアカデミア(3.7)
# 2014              NARUTO-ナルト-(4.6)                食戟のソーマ(5.7)
# 2015              僕のヒーローアカデミア(3.9)                食戟のソーマ(5.7)
# 2016                     暗殺教室(4.1)               ハイキュー!!(5.0)
# 2017                ブラッククローバー(5.7)               ハイキュー!!(5.8)
#
# 年間順位                          5
# 年
# 1970                アニマル球場(5.3)
# 1971               トイレット博士(4.9)
# 1972                ハレンチ学園(4.4)
# 1973               男一匹ガキ大将(3.5)
# 1974                 包丁人味平(5.3)
# 1975                アストロ球団(5.2)
# 1976             1・2のアッホ!!(6.0)
# 1977            すすめ!!パイレーツ(6.0)
# 1978             ルーズ!ルーズ!!(6.2)
# 1979                私立極道高校(4.7)
# 1980               激!!極虎一家(5.8)
# 1981              青空フィッシング(5.7)
# 1982                キャプテン翼(5.6)
# 1983                キャプテン翼(5.5)
# 1984                キャプテン翼(5.8)
# 1985  CITY HUNTER シティ・ハンター(6.1)
# 1986  CITY HUNTER シティ・ハンター(7.3)
# 1987         ゆうれい小僧がやってきた!(6.8)
# 1988              神様はサウスポー(5.8)
# 1989              CYBERブルー(6.6)
# 1990          花の慶次-雲のかなたに-(6.0)
# 1991     ペナントレース やまだたいちの奇蹟(7.2)
# 1992            ろくでなしBLUES(5.4)
# 1993   DRAGON QUEST ダイの大冒険(8.3)
# 1994     BOY-ボーイ-HARELUYAⅡ(6.6)
# 1995             みどりのマキバオー(7.6)
# 1996     BOY-ボーイ-HARELUYAⅡ(5.9)
# 1997                  封神演義(4.7)
# 1998                   カジカ(6.6)
# 1999      るろうに剣心 -明治剣客浪漫譚-(5.5)
# 2000          世紀末リーダー伝たけし!(5.6)
# 2001            ボボボーボ・ボーボボ(5.6)
# 2002                 遊☆戯☆王(5.1)
# 2003                 ヒカルの碁(7.1)
# 2004            DEATH NOTE(5.7)
# 2005                    銀魂(7.4)
# 2006      家庭教師ヒットマンREBORN!(6.2)
# 2007      家庭教師ヒットマンREBORN!(5.8)
# 2008      家庭教師ヒットマンREBORN!(5.9)
# 2009      家庭教師ヒットマンREBORN!(6.9)
# 2010                  エニグマ(6.8)
# 2011                 バクマン。(6.4)
# 2012               斉木楠雄のΨ難(5.9)
# 2013                黒子のバスケ(5.9)
# 2014                黒子のバスケ(5.8)
# 2015               ハイキュー!!(5.8)
# 2016             ブラッククローバー(5.1)
# 2017             約束のネバーランド(6.1)

# %% [markdown]
# ## 各作品の掲載順推移

# %%
# 指定したタイトルの順位の時系列プロットを可視化する関数
def plot_rank(df,titles):
  fig = px.line(df[df["タイトル"].isin(titles)],
                x='公開年月日',
                # x='疑似年月日',
                y="掲載順位",color='タイトル',
                hover_data=["タイトル","サブタイトル"])
  fig.update_layout(hovermode="x")
  fig.update_yaxes(autorange='reversed')
  fig.update_traces(
          hovertemplate ="<b>%{y}位</b>：%{customdata[0]}<br>%{customdata[1]}",
          mode='lines+markers',
          marker=dict(line_width=1, size=10))
  fig.update_layout(
      xaxis=dict(
        tickformat="%m月%d日\n%Y",
        rangeslider=dict(visible=True),
        type="date",
        rangeselector=dict(  # ズーム幅をボタンで切り替えられるようにする
          buttons=list([
            dict(count=1,label="1y",step="year",stepmode="backward"),
            dict(count=2,label="2y",step="year",stepmode="backward"),
            dict(count=3,label="3y",step="year",stepmode="backward"),
            dict(step="all")
          ])
        )
      ),
      yaxis=dict(
        fixedrange= True  # y軸のズーム禁止
      )
  )
  fig.show()

# %%
# 掲載順位の推移をみるタイトル
target_titles = [
    "ONE PIECE",
    "NARUTO-ナルト-",
    "暗殺教室",
    "僕のヒーローアカデミア"
]

# 可視化
plot_rank(df,target_titles)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e6426903-cf71-4647-ba4d-846c48d3e065" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6426903-cf71-4647-ba4d-846c48d3e065")) {                    Plotly.newPlot(                        "e6426903-cf71-4647-ba4d-846c48d3e065",                        [{"customdata":[["ONE PIECE","1.ROMANCE DAWN\u2015\u5192\u967a\u306e\u591c\u660e\u3051\u2015"],["ONE PIECE","\u7b2c2\u8a71!! \u305d\u306e\u7537\u201c\u9ea6\u308f\u3089\u306e\u30eb\u30d5\u30a3\u201d"],["ONE PIECE","\u7b2c3\u8a71 \u201c\u6d77\u8cca\u72e9\u308a\u306e\u30be\u30ed\u201d\u767b\u5834"],["ONE PIECE","\u7b2c4\u8a71 \u6d77\u8ecd\u5927\u4f50\u201c\u65a7\u624b\u306e\u30e2\u30fc\u30ac\u30f3\u201d"],["ONE PIECE","\u7b2c5\u8a71 \u201c\u6d77\u8cca\u738b\u3068\u5927\u5263\u8c6a\u201d"],["ONE PIECE","\u7b2c6\u8a71 \u201c1\u4eba\u76ee\u201d"],["ONE PIECE","\u7b2c7\u8a71 \u201c\u53cb\u9054\u201d"],["ONE PIECE","\u7b2c8\u8a71 \u201c\u30ca\u30df\u767b\u5834\u201d"],["ONE PIECE","\u7b2c9\u8a71 \u201c\u9b54\u6027\u306e\u5973\u201d"],["ONE PIECE","\u7b2c10\u8a71 \u201c\u9152\u5834\u306e\u4e00\u4ef6\u201d"],["ONE PIECE","\u7b2c11\u8a71 \u201c\u6557\u8d70\u201d"],["ONE PIECE","\u7b2c12\u8a71 \u201c\u72ac\u201d"],["ONE PIECE","\u7b2c13\u8a71 \u201c\u5b9d\u7269\u201d"],["ONE PIECE","\u7b2c14\u8a71 \u201c\u7121\u8b00\u3063!!\u201d"],["ONE PIECE","\u7b2c15\u8a71 \u201cGONG\u201d"],["ONE PIECE","\u7b2c16\u8a71 \u201cVERSUS!!\u30d0\u30ae\u30fc\u6d77\u8cca\u8239\u201d"],["ONE PIECE","\u7b2c17\u8a71 \u201c\u683c\u201d"],["ONE PIECE","\u7b2c18\u8a71 \u6d77\u8cca\u201c\u9053\u5316\u306e\u30d0\u30ae\u30fc\u201d"],["ONE PIECE","\u7b2c19\u8a71 \u201c\u60aa\u9b54\u306e\u5b9f\u201d"],["ONE PIECE","\u7b2c20\u8a71 \u201c\u6ce5\u68d2\u9053\u201d"],["ONE PIECE","\u7b2c21\u8a71 \u201c\u8857\u201d"],["ONE PIECE","\u7b2c22\u8a71 \u201c\u3042\u3093\u305f\u304c\u73cd\u7363\u201d"],["ONE PIECE","\u7b2c23\u8a71 \u201c\u30ad\u30e3\u30d7\u30c6\u30f3\u30fb\u30a6\u30bd\u30c3\u30d7\u767b\u5834\u201d"],["ONE PI